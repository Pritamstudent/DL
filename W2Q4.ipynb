# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess data
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# Define models with different activation functions

# ReLU activation
model_relu = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Sigmoid activation
model_sigmoid = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='sigmoid'),
    Dense(64, activation='sigmoid'),
    Dense(10, activation='softmax')
])

# Tanh activation
model_tanh = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='tanh'),
    Dense(64, activation='tanh'),
    Dense(10, activation='softmax')
])

# Compile models
model_relu.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

model_sigmoid.compile(optimizer='adam',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

model_tanh.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

# Train models
history_relu = model_relu.fit(train_images, train_labels, epochs=5, batch_size=128, validation_split=0.2)

history_sigmoid = model_sigmoid.fit(train_images, train_labels, epochs=5, batch_size=128, validation_split=0.2)

history_tanh = model_tanh.fit(train_images, train_labels, epochs=5, batch_size=128, validation_split=0.2)

# Evaluate models
test_loss_relu, test_acc_relu = model_relu.evaluate(test_images, test_labels)
test_loss_sigmoid, test_acc_sigmoid = model_sigmoid.evaluate(test_images, test_labels)
test_loss_tanh, test_acc_tanh = model_tanh.evaluate(test_images, test_labels)

print("ReLU Model Test Accuracy:", test_acc_relu)
print("Sigmoid Model Test Accuracy:", test_acc_sigmoid)
print("Tanh Model Test Accuracy:", test_acc_tanh)
# Out:
# Epoch 1/5
# 375/375 [==============================] - 3s 4ms/step - loss: 0.3714 - accuracy: 0.8956 - val_loss: 0.1756 - val_accuracy: 0.9508
# Epoch 2/5
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1499 - accuracy: 0.9556 - val_loss: 0.1308 - val_accuracy: 0.9617
# Epoch 3/5
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1049 - accuracy: 0.9692 - val_loss: 0.1121 - val_accuracy: 0.9667
# Epoch 4/5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0801 - accuracy: 0.9762 - val_loss: 0.1032 - val_accuracy: 0.9691
# Epoch 5/5
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0627 - accuracy: 0.9814 - val_loss: 0.0955 - val_accuracy: 0.9718
# Epoch 1/5
# 375/375 [==============================] - 2s 4ms/step - loss: 0.9062 - accuracy: 0.7982 - val_loss: 0.3607 - val_accuracy: 0.9090
# Epoch 2/5
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3071 - accuracy: 0.9168 - val_loss: 0.2443 - val_accuracy: 0.9312
# Epoch 3/5
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2277 - accuracy: 0.9350 - val_loss: 0.1977 - val_accuracy: 0.9448
# Epoch 4/5
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1826 - accuracy: 0.9474 - val_loss: 0.1699 - val_accuracy: 0.9528
# Epoch 5/5
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1514 - accuracy: 0.9560 - val_loss: 0.1491 - val_accuracy: 0.9572
# Epoch 1/5
# 375/375 [==============================] - 2s 3ms/step - loss: 0.3796 - accuracy: 0.8935 - val_loss: 0.2114 - val_accuracy: 0.9423
# Epoch 2/5
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1840 - accuracy: 0.9466 - val_loss: 0.1595 - val_accuracy: 0.9540
# Epoch 3/5
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1314 - accuracy: 0.9619 - val_loss: 0.1283 - val_accuracy: 0.9629
# Epoch 4/5
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1006 - accuracy: 0.9699 - val_loss: 0.1201 - val_accuracy: 0.9644
# Epoch 5/5
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0785 - accuracy: 0.9773 - val_loss: 0.1088 - val_accuracy: 0.9659
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0891 - accuracy: 0.9732
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1487 - accuracy: 0.9555
# 313/313 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9673
# ReLU Model Test Accuracy: 0.9732000231742859
# Sigmoid Model Test Accuracy: 0.9555000066757202
# Tanh Model Test Accuracy: 0.9672999978065491
